# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/drbob-richardson/stat220/blob/main/Assignments/Stat_220_HW1.ipynb)

# %% [markdown]
# **Problem 1**. Give an example of a variable that is (a) categorical; (b) quantitative; (c) discrete; (d) continuous.

# %% [markdown]
# a: Race: Asian, Hispanic, African American
# b: Age of people example: 17 years old
# c: Number of pages in Book of mormon: only whole values like 123,234 page
# d: Length: measure percisly: 3.1415cm

# %% [markdown]
# **Problem 2**. Analyze the Carbon_West data file using the following code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
carbon_west = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Carbon_West.dat")

# %% [markdown]
# Part a. Construct a histogram of CO2 emissions.

# %%
plt.hist(carbon_west['CO2'], bins=20, edgecolor='black')
plt.xlabel('CO2')
plt.ylabel('Frequency')
plt.title('Histogram of CO2')

plt.show()

# %% [markdown]
# Part b. Find the mean, median, and standard deviation.

# %%
# Calculate mean, median, and standard deviation
mean_value = np.mean(carbon_west['CO2'])
median_value = np.median(carbon_west['CO2'])
std_deviation = np.std(carbon_west['CO2'])
variance = np.var(carbon_west['CO2'])

# Display the results
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Standard Deviation: {std_deviation}")
print(f"Variance: {variance}")
# Out:
# Mean: 6.717142857142858
# Median: 5.9
# Standard Deviation: 3.3086454469884727
# Variance: 10.94713469387755

# %% [markdown]
# **Problem 3**. Read in the murder data set using the following code. The variable murder is the murder rate (per 100,000 population) for each state in the U.S. in 2017 according to the FBI Uniform Crime Reports. At first, do not use the observation for D.C. (DC).

# %%
murders = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Murder.dat")

# %% [markdown]
# Part a. Find the mean and standard deviation for murders without D.C.

# %%
murders_without_dc = murders[murders['state'] != 'DC']
mean_value = np.mean(murders_without_dc['murder'])
std_deviation = np.std(murders_without_dc['murder'])
mean_value, std_deviation
# Out:
# (4.874, 2.560297638947472)

# %% [markdown]
# Part b. Find the five-number  summary without D.C.

# %%
minimum = np.min(murders_without_dc['murder'])
q1 = np.percentile(murders_without_dc['murder'], 25)
median = np.median(murders_without_dc['murder'])
q3 = np.percentile(murders_without_dc['murder'], 75)
maximum = np.max(murders_without_dc['murder'])

# Display the five-number summary
print(f"Minimum: {minimum}")
print(f"1st Quartile (Q1): {q1}")
print(f"Median (Q2): {median}")
print(f"3rd Quartile (Q3): {q3}")
print(f"Maximum: {maximum}")
murders_without_dc['murder'].describe()
# Out:
# Minimum: 1.0
# 1st Quartile (Q1): 2.625
# Median (Q2): 4.85
# 3rd Quartile (Q3): 6.175
# Maximum: 12.4
# count    50.000000
# mean      4.874000
# std       2.586291
# min       1.000000
# 25%       2.625000
# 50%       4.850000
# 75%       6.175000
# max      12.400000
# Name: murder, dtype: float64

# %% [markdown]
# Part c. Now include the observation for D.C. and recalculate the mean, median, and five-number summary. What is affected more by this outlier: The mean or the median? The range or the inter-quartile range?

# %%
# Calculate mean, median, and standard deviation with D.C.
mean_value_with_dc = np.mean(murders['murder'])
median_value_with_dc = np.median(murders['murder'])
minimum_with_dc = np.min(murders['murder'])
q1_with_dc = np.percentile(murders['murder'], 25)
q3_with_dc = np.percentile(murders['murder'], 75)
maximum_with_dc = np.max(murders['murder'])

# Display the results
print(f"Mean (with D.C.): {mean_value_with_dc}")
print(f"Median (with D.C.): {median_value_with_dc}")
print(f"Minimum (with D.C.): {minimum_with_dc}")
print(f"1st Quartile (Q1) (with D.C.): {q1_with_dc}")
print(f"Median (Q2) (with D.C.): {median_value_with_dc}")
print(f"3rd Quartile (Q3) (with D.C.): {q3_with_dc}")
print(f"Maximum (with D.C.): {maximum_with_dc}")

# Calculate the differences
mean_difference = mean_value_with_dc - mean_value
median_difference = median_value_with_dc - median
range_difference_with_dc = maximum_with_dc - minimum_with_dc
range_difference_without_dc = maximum - minimum
iqr_with_dc = q3_with_dc - q1_with_dc
iqr_without_dc = q3-q1

print(mean_difference)
print(median_difference)

print(range_difference_with_dc-range_difference_without_dc)
print(iqr_with_dc-iqr_without_dc)

five_number_summary_with_dc = murders['murder'].describe()
print(five_number_summary_with_dc)

plt.figure(figsize=(8, 6))
murders.boxplot(column='murder', vert=False,grid = False)
plt.title('With DC')
plt.xlabel('Murder')
plt.ylabel('State')
plt.show()

plt.figure(figsize=(8, 6))
murders_without_dc.boxplot(column='murder', vert=False,grid = False)
plt.title('Without DC')
plt.xlabel('Murder')
plt.ylabel('State')
plt.show()

# The Mean and the range are affected more
# Out:
# Mean (with D.C.): 5.252941176470588
# Median (with D.C.): 5.0
# Minimum (with D.C.): 1.0
# 1st Quartile (Q1) (with D.C.): 2.6500000000000004
# Median (Q2) (with D.C.): 5.0
# 3rd Quartile (Q3) (with D.C.): 6.45
# Maximum (with D.C.): 24.2
# 0.37894117647058856
# 0.15000000000000036
# 11.799999999999999
# 0.25
# count    51.000000
# mean      5.252941
# std       3.725391
# min       1.000000
# 25%       2.650000
# 50%       5.000000
# 75%       6.450000
# max      24.200000
# Name: murder, dtype: float64

# %% [markdown]
# **Problem 4**. Read in the Houses data file using the following code.  The variables include price (thousands of dollars), size (square feet), tax bill (dollars), number of bathrooms, number of bedrooms, and whether the house is new (1 = yes, 0 = no) for 100 home sales in Gainesville, Florida. Let
# y = selling price and x = size of home.

# %%
houses = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Houses.dat")

# %% [markdown]
# Part a. Construct a scatterplot between square feet and price of a home.

# %%
plt.scatter(houses['size'], houses['price'])
plt.xlabel('Square Feet')
plt.ylabel('Price')
plt.title('Scatterplot of Square Feet vs Price')

plt.show()

# %% [markdown]
# Part b. Find the correlation between the two variables.

# %%
correlation = houses['size'].corr(houses['price'])
correlation
# Out:
# 0.8337847885586537

# %% [markdown]
# Part c. Find and plot the regression line on top of the scatterplot.

# %%
# Extract the variables
x = houses['size']
y = houses['price']

# Calculate the regression line
slope, intercept = np.polyfit(x, y, 1)
regression_line = slope * x + intercept

# Plot the scatterplot
plt.scatter(x, y)
plt.xlabel('Square Feet')
plt.ylabel('Price')
plt.title('Scatterplot of Square Feet vs Price')

# Plot the regression line
plt.plot(x, regression_line, color='red')

plt.show()

# %% [markdown]
# Part d. Create a side by side boxplot of price comparing homes that are new and homes that are not new.

# %%
# Create a figure and axis
fig, ax = plt.subplots()

# Create a side by side boxplot
ax.boxplot([houses[houses['new'] == 0]['price'], houses[houses['new'] == 1]['price']], labels=['Not New', 'New'])

# Set the labels and title
ax.set_xlabel('Home Type')
ax.set_ylabel('Price')
ax.set_title('Comparison of Price for New and Not New Homes')

# Show the plot
plt.show()
# Out:
# /var/folders/c3/9xbk45sx2ss9xbg__5xhz0kc0000gn/T/ipykernel_56112/3989625154.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([houses[houses['new'] == 0]['price'], houses[houses['new'] == 1]['price']], labels=['Not New', 'New'])

# %% [markdown]
# Part e. What is the relationship between size and price.  Justify your answer using the plots created. Do the same for the relationship between price and whether or not a house is new, again using the plot to justify your answer.

# %% [markdown]
# By examining the scatterplot created, we can see a positive correlation between size and price. As the size of the house increases, the price tends to increase. This is indicated by the upward trend in the scatterplot.
#
# Similarly, by examining the boxplot created, we can see that new homes generally have higher prices compared to not new homes. This is indicated by the higher median price for new homes in the boxplot.

# %% [markdown]
# **Problem 1.22**. Using the Happy data file read in by the following code. Construct the contingency table relating marital status and happiness.

# %%
happy = pd.read_fwf("https://stat4ds.rwth-aachen.de/data/Happy.dat")

# %%
contingency_table = pd.crosstab(happy['marital'], happy['happiness'],normalize = "index")
contingency_table
# Out:
# happiness         1   1     1   1     2  1     3        2   2     1   2     2  \
# marital
# fe         0.304462  0.000000  0.000000  0.00000  0.56168  0.000000  0.000000
# fem        0.000000  1.000000  0.000000  0.00000  0.00000  0.000000  0.000000
# mal        0.000000  0.119553  0.036872  0.06257  0.00000  0.255866  0.127374
# male       0.000000  1.000000  0.000000  0.00000  0.00000  0.000000  0.000000
#
# happiness   2     3         3   3     1   3     2   3     3
# marital
# fe         0.000000  0.133858  0.000000  0.000000  0.000000
# fem        0.000000  0.000000  0.000000  0.000000  0.000000
# mal        0.234637  0.000000  0.036872  0.050279  0.075978
# male       0.000000  0.000000  0.000000  0.000000  0.000000
